# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

def getNgrams(content, n):
  content = content.split(' ')
  output = []
  for i in range(len(content)-n+1):
    output.append(content[i:i+n])
  return output

html = urlopen('http://en.wikipedia.org/wiki/Python_(programming_language)')
bs = BeautifulSoup(html, 'html.parser')
content = bs.find('div', {'id':'mw-content-text'}).get_text()
ngrams = getNgrams(content, 2)
print(ngrams)
print('2-grams count is: '+str(len(ngrams)))
# Out:
# [['General-purpose,', 'high-level'], ['high-level', 'programming'], ['programming', 'language\n\n\nFor'], ['language\n\n\nFor', 'other'], ['other', 'uses,'], ['uses,', 'see'], ['see', 'Python'], ['Python', '(disambiguation).\nPythonParadigmMulti-paradigm:'], ['(disambiguation).\nPythonParadigmMulti-paradigm:', 'object-oriented,[1]'], ['object-oriented,[1]', 'procedural'], ['procedural', '(imperative),'], ['(imperative),', 'functional,'], ['functional,', 'structured,'], ['structured,', 'reflectiveDesigned\xa0byGuido'], ['reflectiveDesigned\xa0byGuido', 'van'], ['van', 'RossumDeveloperPython'], ['RossumDeveloperPython', 'Software'], ['Software', 'FoundationFirst\xa0appearedFebruary\xa020,'], ['FoundationFirst\xa0appearedFebruary\xa020,', '1991;'], ['1991;', '30'], ['30', 'years'], ['years', 'ago\xa0(1991-02-20)[2]Stable'], ['ago\xa0(1991-02-20)[2]Stable', 'release3.9.7[3]\xa0\n'], ['release3.9.7[3]\xa0\n', ''], ['', ''], ['', '/'], ['/', '30'], ['30', 'August'], ['August', '2021;'], ['2021;', '23'], ['23', 'days'], ['days', 'ago\xa0(30'], ['ago\xa0(30', 'August'], ['August', '2021)\nTyping'], ['2021)\nTyping', 'disciplineDuck,'], ['disciplineDuck,', 'dynamic,'], ['dynamic,', 'strong'], ['strong', 'typing;[4]'], ['typing;[4]', 'gradual'], ['gradual', '(since'], ['(since', '3.5,'], ['3.5,', 'but'], ['but', 'ignored'], ['ignored', 'in'], ['in', 'CPython)[5]OSWindows,'], ['CPython)[5]OSWindows,', 'Linux/UNIX,'], ['Linux/UNIX,', 'macOS'], ['macOS', 'and'], ['and', 'more[6]LicensePython'], ['more[6]LicensePython', 'Software'], ['Software', 'Foundation'], ['Foundation', 'LicenseFilename'], ['LicenseFilename', 'extensions.py,'], ['extensions.py,', '.pyi,'], ['.pyi,', '.pyc,'], ['.pyc,', '.pyd,'], ['.pyd,', '.pyo'], ['.pyo', '(prior'], ['(prior', 'to'], ['to', '3.5),[7]'], ['3.5),[7]', '.pyw,'], ['.pyw,', '.pyz'], ['.pyz', '(since'], ['(since', '3.5)[8]Websitewww.python.orgMajor'], ['3.5)[8]Websitewww.python.orgMajor', 'implementationsCPython,'], ['implementationsCPython,', 'PyPy,'], ['PyPy,', 'Stackless'], ['Stackless', 'Python,'], ['Python,', 'MicroPython,'], ['MicroPython,', 'CircuitPython,'], ['CircuitPython,', 'IronPython,'], ['IronPython,', 'JythonDialectsCython,'], ['JythonDialectsCython,', 'RPython,'], ['RPython,', 'Starlark[9]Influenced'], ['Starlark[9]Influenced', 'byABC,[10]'], ['byABC,[10]', 'Ada,[11]'], ['Ada,[11]', 'ALGOL'], ['ALGOL', '68,[12]'], ['68,[12]', 'APL,[13]'], ['APL,[13]', 'C,[14]'], ['C,[14]', 'C++,[15]'], ['C++,[15]', 'CLU,[16]'], ['CLU,[16]', 'Dylan,[17]'], ['Dylan,[17]', 'Haskell,[18]'], ['Haskell,[18]', 'Icon,[19]'], ['Icon,[19]', 'Java,[20]'], ['Java,[20]', 'Lisp,[21]'], ['Lisp,[21]', 'Modula-3,[15]'], ['Modula-3,[15]', 'Perl,'], ['Perl,', 'Standard'], ['Standard', 'ML[13]InfluencedApache'], ['ML[13]InfluencedApache', 'Groovy,'], ['Groovy,', 'Boo,'], ['Boo,', 'Cobra,'], ['Cobra,', 'CoffeeScript,[22]'], ['CoffeeScript,[22]', 'D,'], ['D,', 'F#,'], ['F#,', 'Genie,[23]'], ['Genie,[23]', 'Go,'], ['Go,', 'JavaScript,[24][25]'], ['JavaScript,[24][25]', 'Julia,[26]'], ['Julia,[26]', 'Nim,'], ['Nim,', 'Ring,[27]'], ['Ring,[27]', 'Ruby,[28]'], ['Ruby,[28]', 'Swift[29]\n'], ['Swift[29]\n', 'Python'], ['Python', 'Programming'], ['Programming', 'at'], ['at', 'Wikibooks\n\nPython'], ['Wikibooks\n\nPython', 'is'], ['is', 'an'], ['an', 'interpreted'], ['interpreted', 'high-level'], ['high-level', 'general-purpose'], ['general-purpose', 'programming'], ['programming', 'language.'], ['language.', 'Its'], ['Its', 'design'], ['design', 'philosophy'], ['philosophy', 'emphasizes'], ['emphasizes', 'code'], ['code', 'readability'], ['readability', 'with'], ['with', 'its'], ['its', 'use'], ['use', 'of'], ['of', 'significant'], ['significant', 'indentation.'], ['indentation.', 'Its'], ['Its', 'language'], ['language', 'constructs'], ['constructs', 'as'], ['as', 'well'], ['well', 'as'], ['as', 'its'], ['its', 'object-oriented'], ['object-oriented', 'approach'], ['approach', 'aim'], ['aim', 'to'], ['to', 'help'], ['help', 'programmers ...
# 2-grams count is: 11589

# %%
import re

def getNgrams(content, n):
    content = re.sub('\n|[[\d+\]]', ' ', content)
    content = bytes(content, 'UTF-8')
    content = content.decode('ascii', 'ignore')
    content = content.split(' ')
    content = [word for word in content if word != '']
    output = []
    for i in range(len(content)-n+1):
        output.append(content[i:i+n])
    return output
html = urlopen('http://en.wikipedia.org/wiki/Python_(programming_language)')
bs = BeautifulSoup(html, 'html.parser')
content = bs.find('div', {'id':'mw-content-text'}).get_text()
ngrams = getNgrams(content, 2)
print(ngrams)
print('2-grams count is: '+str(len(ngrams)))
# Out:
# [['General-purpose,', 'high-level'], ['high-level', 'programming'], ['programming', 'language'], ['language', 'For'], ['For', 'other'], ['other', 'uses,'], ['uses,', 'see'], ['see', 'Python'], ['Python', '(disambiguation).'], ['(disambiguation).', 'PythonParadigmMulti-paradigm:'], ['PythonParadigmMulti-paradigm:', 'object-oriented,'], ['object-oriented,', 'procedural'], ['procedural', '(imperative),'], ['(imperative),', 'functional,'], ['functional,', 'structured,'], ['structured,', 'reflectiveDesignedbyGuido'], ['reflectiveDesignedbyGuido', 'van'], ['van', 'RossumDeveloperPython'], ['RossumDeveloperPython', 'Software'], ['Software', 'FoundationFirstappearedFebruary'], ['FoundationFirstappearedFebruary', ','], [',', ';'], [';', 'years'], ['years', 'ago('], ['ago(', '-'], ['-', '-'], ['-', ')'], [')', 'Stable'], ['Stable', 'release'], ['release', '.'], ['.', '.'], ['.', '/'], ['/', 'August'], ['August', ';'], [';', 'days'], ['days', 'ago('], ['ago(', 'August'], ['August', ')'], [')', 'Typing'], ['Typing', 'disciplineDuck,'], ['disciplineDuck,', 'dynamic,'], ['dynamic,', 'strong'], ['strong', 'typing;'], ['typing;', 'gradual'], ['gradual', '(since'], ['(since', '.'], ['.', ','], [',', 'but'], ['but', 'ignored'], ['ignored', 'in'], ['in', 'CPython)'], ['CPython)', 'OSWindows,'], ['OSWindows,', 'Linux/UNIX,'], ['Linux/UNIX,', 'macOS'], ['macOS', 'and'], ['and', 'more'], ['more', 'LicensePython'], ['LicensePython', 'Software'], ['Software', 'Foundation'], ['Foundation', 'LicenseFilename'], ['LicenseFilename', 'extensions.py,'], ['extensions.py,', '.pyi,'], ['.pyi,', '.pyc,'], ['.pyc,', '.pyd,'], ['.pyd,', '.pyo'], ['.pyo', '(prior'], ['(prior', 'to'], ['to', '.'], ['.', '),'], ['),', '.pyw,'], ['.pyw,', '.pyz'], ['.pyz', '(since'], ['(since', '.'], ['.', ')'], [')', 'Websitewww.python.orgMajor'], ['Websitewww.python.orgMajor', 'implementationsCPython,'], ['implementationsCPython,', 'PyPy,'], ['PyPy,', 'Stackless'], ['Stackless', 'Python,'], ['Python,', 'MicroPython,'], ['MicroPython,', 'CircuitPython,'], ['CircuitPython,', 'IronPython,'], ['IronPython,', 'JythonDialectsCython,'], ['JythonDialectsCython,', 'RPython,'], ['RPython,', 'Starlark'], ['Starlark', 'Influenced'], ['Influenced', 'byABC,'], ['byABC,', 'Ada,'], ['Ada,', 'ALGOL'], ['ALGOL', ','], [',', 'APL,'], ['APL,', 'C,'], ['C,', 'C'], ['C', ','], [',', 'CLU,'], ['CLU,', 'Dylan,'], ['Dylan,', 'Haskell,'], ['Haskell,', 'Icon,'], ['Icon,', 'Java,'], ['Java,', 'Lisp,'], ['Lisp,', 'Modula-'], ['Modula-', ','], [',', 'Perl,'], ['Perl,', 'Standard'], ['Standard', 'ML'], ['ML', 'InfluencedApache'], ['InfluencedApache', 'Groovy,'], ['Groovy,', 'Boo,'], ['Boo,', 'Cobra,'], ['Cobra,', 'CoffeeScript,'], ['CoffeeScript,', 'D,'], ['D,', 'F#,'], ['F#,', 'Genie,'], ['Genie,', 'Go,'], ['Go,', 'JavaScript,'], ['JavaScript,', 'Julia,'], ['Julia,', 'Nim,'], ['Nim,', 'Ring,'], ['Ring,', 'Ruby,'], ['Ruby,', 'Swift'], ['Swift', 'Python'], ['Python', 'Programming'], ['Programming', 'at'], ['at', 'Wikibooks'], ['Wikibooks', 'Python'], ['Python', 'is'], ['is', 'an'], ['an', 'interpreted'], ['interpreted', 'high-level'], ['high-level', 'general-purpose'], ['general-purpose', 'programming'], ['programming', 'language.'], ['language.', 'Its'], ['Its', 'design'], ['design', 'philosophy'], ['philosophy', 'emphasizes'], ['emphasizes', 'code'], ['code', 'readability'], ['readability', 'with'], ['with', 'its'], ['its', 'use'], ['use', 'of'], ['of', 'significant'], ['significant', 'indentation.'], ['indentation.', 'Its'], ['Its', 'language'], ['language', 'constructs'], ['constructs', 'as'], ['as', 'well'], ['well', 'as'], ['as', 'its'], ['its', 'object-oriented'], ['object-oriented', 'approach'], ['approach', 'aim'], ['aim', 'to'], ['to', 'help'], ['help', 'programmers'], ['programmers', 'write'], ['write', 'clear,'], ['clear,', 'logical'], ['logical', 'code'], ['code', 'for'], ['for', 'small'], ['small', 'and'], ['and', 'large-scale'], ['large-scale', 'projects.'], ['projects.', 'Python'], ['Python', 'is' ...
# 2-grams count is: 12369
# <ipython-input-4-5d9dceb195ee>:4: FutureWarning: Possible nested set at position 3
#   content = re.sub('\n|[[\d+\]]', ' ', content)

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
import string

def cleanSentence(sentence):
    sentence = sentence.split(' ')
    sentence = [word.strip(string.punctuation+string.whitespace) for word in sentence]
    sentence = [word for word in sentence if len(word) > 1 or (word.lower() == 'a' or word.lower() == 'i')]
    return sentence

def cleanInput(content):
    content = content.upper()
    content = re.sub('\n|[[\d+\]]', ' ', content)
    content = bytes(content, "UTF-8")
    content = content.decode("ascii", "ignore")
    sentences = content.split('. ')
    return [cleanSentence(sentence) for sentence in sentences]

def getNgramsFromSentence(content, n):
    output = []
    for i in range(len(content)-n+1):
        output.append(content[i:i+n])
    return output

def getNgrams(content, n):
    content = cleanInput(content)
    ngrams = []
    for sentence in content:
        ngrams.extend(getNgramsFromSentence(sentence, n))
    return(ngrams)


html = urlopen('http://en.wikipedia.org/wiki/Python_(programming_language)')
bs = BeautifulSoup(html, 'html.parser')
content = bs.find('div', {'id':'mw-content-text'}).get_text()
print(len(getNgrams(content, 2)))
# Out:
# 9364

# %%
print(getNgrams(content, 2))
# Out:
# [['GENERAL-PURPOSE', 'HIGH-LEVEL'], ['HIGH-LEVEL', 'PROGRAMMING'], ['PROGRAMMING', 'LANGUAGE'], ['LANGUAGE', 'FOR'], ['FOR', 'OTHER'], ['OTHER', 'USES'], ['USES', 'SEE'], ['SEE', 'PYTHON'], ['PYTHON', 'DISAMBIGUATION'], ['PYTHONPARADIGMMULTI-PARADIGM', 'OBJECT-ORIENTED'], ['OBJECT-ORIENTED', 'PROCEDURAL'], ['PROCEDURAL', 'IMPERATIVE'], ['IMPERATIVE', 'FUNCTIONAL'], ['FUNCTIONAL', 'STRUCTURED'], ['STRUCTURED', 'REFLECTIVEDESIGNEDBYGUIDO'], ['REFLECTIVEDESIGNEDBYGUIDO', 'VAN'], ['VAN', 'ROSSUMDEVELOPERPYTHON'], ['ROSSUMDEVELOPERPYTHON', 'SOFTWARE'], ['SOFTWARE', 'FOUNDATIONFIRSTAPPEAREDFEBRUARY'], ['FOUNDATIONFIRSTAPPEAREDFEBRUARY', 'YEARS'], ['YEARS', 'AGO'], ['AGO', 'STABLE'], ['STABLE', 'RELEASE'], ['AUGUST', 'DAYS'], ['DAYS', 'AGO'], ['AGO', 'AUGUST'], ['AUGUST', 'TYPING'], ['TYPING', 'DISCIPLINEDUCK'], ['DISCIPLINEDUCK', 'DYNAMIC'], ['DYNAMIC', 'STRONG'], ['STRONG', 'TYPING'], ['TYPING', 'GRADUAL'], ['GRADUAL', 'SINCE'], ['BUT', 'IGNORED'], ['IGNORED', 'IN'], ['IN', 'CPYTHON'], ['CPYTHON', 'OSWINDOWS'], ['OSWINDOWS', 'LINUX/UNIX'], ['LINUX/UNIX', 'MACOS'], ['MACOS', 'AND'], ['AND', 'MORE'], ['MORE', 'LICENSEPYTHON'], ['LICENSEPYTHON', 'SOFTWARE'], ['SOFTWARE', 'FOUNDATION'], ['FOUNDATION', 'LICENSEFILENAME'], ['LICENSEFILENAME', 'EXTENSIONS.PY'], ['EXTENSIONS.PY', 'PYI'], ['PYI', 'PYC'], ['PYC', 'PYD'], ['PYD', 'PYO'], ['PYO', 'PRIOR'], ['PRIOR', 'TO'], ['PYW', 'PYZ'], ['PYZ', 'SINCE'], ['WEBSITEWWW.PYTHON.ORGMAJOR', 'IMPLEMENTATIONSCPYTHON'], ['IMPLEMENTATIONSCPYTHON', 'PYPY'], ['PYPY', 'STACKLESS'], ['STACKLESS', 'PYTHON'], ['PYTHON', 'MICROPYTHON'], ['MICROPYTHON', 'CIRCUITPYTHON'], ['CIRCUITPYTHON', 'IRONPYTHON'], ['IRONPYTHON', 'JYTHONDIALECTSCYTHON'], ['JYTHONDIALECTSCYTHON', 'RPYTHON'], ['RPYTHON', 'STARLARK'], ['STARLARK', 'INFLUENCED'], ['INFLUENCED', 'BYABC'], ['BYABC', 'ADA'], ['ADA', 'ALGOL'], ['ALGOL', 'APL'], ['APL', 'CLU'], ['CLU', 'DYLAN'], ['DYLAN', 'HASKELL'], ['HASKELL', 'ICON'], ['ICON', 'JAVA'], ['JAVA', 'LISP'], ['LISP', 'MODULA'], ['MODULA', 'PERL'], ['PERL', 'STANDARD'], ['STANDARD', 'ML'], ['ML', 'INFLUENCEDAPACHE'], ['INFLUENCEDAPACHE', 'GROOVY'], ['GROOVY', 'BOO'], ['BOO', 'COBRA'], ['COBRA', 'COFFEESCRIPT'], ['COFFEESCRIPT', 'GENIE'], ['GENIE', 'GO'], ['GO', 'JAVASCRIPT'], ['JAVASCRIPT', 'JULIA'], ['JULIA', 'NIM'], ['NIM', 'RING'], ['RING', 'RUBY'], ['RUBY', 'SWIFT'], ['SWIFT', 'PYTHON'], ['PYTHON', 'PROGRAMMING'], ['PROGRAMMING', 'AT'], ['AT', 'WIKIBOOKS'], ['WIKIBOOKS', 'PYTHON'], ['PYTHON', 'IS'], ['IS', 'AN'], ['AN', 'INTERPRETED'], ['INTERPRETED', 'HIGH-LEVEL'], ['HIGH-LEVEL', 'GENERAL-PURPOSE'], ['GENERAL-PURPOSE', 'PROGRAMMING'], ['PROGRAMMING', 'LANGUAGE'], ['ITS', 'DESIGN'], ['DESIGN', 'PHILOSOPHY'], ['PHILOSOPHY', 'EMPHASIZES'], ['EMPHASIZES', 'CODE'], ['CODE', 'READABILITY'], ['READABILITY', 'WITH'], ['WITH', 'ITS'], ['ITS', 'USE'], ['USE', 'OF'], ['OF', 'SIGNIFICANT'], ['SIGNIFICANT', 'INDENTATION'], ['ITS', 'LANGUAGE'], ['LANGUAGE', 'CONSTRUCTS'], ['CONSTRUCTS', 'AS'], ['AS', 'WELL'], ['WELL', 'AS'], ['AS', 'ITS'], ['ITS', 'OBJECT-ORIENTED'], ['OBJECT-ORIENTED', 'APPROACH'], ['APPROACH', 'AIM'], ['AIM', 'TO'], ['TO', 'HELP'], ['HELP', 'PROGRAMMERS'], ['PROGRAMMERS', 'WRITE'], ['WRITE', 'CLEAR'], ['CLEAR', 'LOGICAL'], ['LOGICAL', 'CODE'], ['CODE', 'FOR'], ['FOR', 'SMALL'], ['SMALL', 'AND'], ['AND', 'LARGE-SCALE'], ['LARGE-SCALE', 'PROJECTS'], ['PYTHON', 'IS'], ['IS', 'DYNAMICALLY-TYPED'], ['DYNAMICALLY-TYPED', 'AND'], ['AND', 'GARBAGE-COLLECTED'], ['IT', 'SUPPORTS'], ['SUPPORTS', 'MULTIPLE'], ['MULTIPLE', 'PROGRAMMING'], ['PROGRAMMING', 'PARADIGMS'], ['PARADIGMS', 'INCLUDING'], ['INCLUDING', 'STRUCTURED'], ['STRUCTURED', 'PARTICULARLY'], ['PARTICULARLY', 'PROCEDURAL'], ['PROCEDURAL', 'OBJECT-ORIENTED'], ['OBJECT-ORIENTED', 'AND'], ['AND', 'FUNCTIONAL'], ['FUNCTIONAL', 'PROGRAMMING'], ['IT', 'IS'], ['IS', 'OFTEN'], ['OFTEN', 'DESCRIBED'], ['DESCRIBED', 'AS'], ['AS', 'A'], ['A', 'BATTERIES'], ['BATTERIES', 'INCLUDED'], ['INCLUDED', 'LANGUAGE'], ['LANGUAGE', 'DUE'], ['DUE', 'TO'], ['TO', ...

# %%
#8.1.1 page 167
